# %%
import pandas as pd;
import numpy as np;

# %%
data=pd.read_csv("googleplaystore.csv");

# %%
data.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# ...

# %%
data["App"]
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10836                                     Sya9a Maroc - FR
# 10837                     Fr. Mike Schmitz Audio Teachings
# 10838                               Parkinson Exercices FR
# 10839                        The SCP Foundation DB fr nn5n
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10841, dtype: object

# %%
for i in data.columns:
    print(data[i][0]);
# Out:
# Photo Editor & Candy Camera & Grid & ScrapBook
# ART_AND_DESIGN
# 4.1
# 159
# 19M
# 10,000+
# Free
# 0
# Everyone
# Art & Design
# January 7, 2018
# 1.0.0
# 4.0.3 and up

# %%
data.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df=data.dropna();

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
avg=sum(df['Rating'])/len(df["Rating"]);
print("The average rating of given apps of playstore is ",float(str(avg)[0:4]));
# Out:
# The average rating of given apps of playstore is  4.19

# %%
c=0;
for i in data["Rating"]:
    if(i==5):
        c=c+1;
print("There are ",c,"apps with rating 5.0");
# Out:
# There are  274 apps with rating 5.0

# %%
df=data["Category"]
# print(df.unique());
for i in df.unique():
    print(i);

print("Total numbers of Category in applications are ",len(df.unique()));
# Out:
# ART_AND_DESIGN
# AUTO_AND_VEHICLES
# BEAUTY
# BOOKS_AND_REFERENCE
# BUSINESS
# COMICS
# COMMUNICATION
# DATING
# EDUCATION
# ENTERTAINMENT
# EVENTS
# FINANCE
# FOOD_AND_DRINK
# HEALTH_AND_FITNESS
# HOUSE_AND_HOME
# LIBRARIES_AND_DEMO
# LIFESTYLE
# GAME
# FAMILY
# MEDICAL
# SOCIAL
# SHOPPING
# PHOTOGRAPHY
# SPORTS
# TRAVEL_AND_LOCAL
# TOOLS
# PERSONALIZATION
# PRODUCTIVITY
# PARENTING
# WEATHER
# VIDEO_PLAYERS
# NEWS_AND_MAGAZINES
# MAPS_AND_NAVIGATION
# 1.9
# Total numbers of Category in applications are  34

# %%
c=0;
for i in df:
    if(i=="ART_AND_DESIGN"):
        c+=1;

print("There are total",c,"applications of ART_AND_DESIGN");
# Out:
# There are total 65 applications of ART_AND_DESIGN

# %%
for i in df.unique():
    c=0;
    for j in df:
        if(i==j):
            c+=1;
    print("Total number of "+i+" applications are ",c);
# Out:
# Total number of ART_AND_DESIGN applications are  65
# Total number of AUTO_AND_VEHICLES applications are  85
# Total number of BEAUTY applications are  53
# Total number of BOOKS_AND_REFERENCE applications are  231
# Total number of BUSINESS applications are  460
# Total number of COMICS applications are  60
# Total number of COMMUNICATION applications are  387
# Total number of DATING applications are  234
# Total number of EDUCATION applications are  156
# Total number of ENTERTAINMENT applications are  149
# Total number of EVENTS applications are  64
# Total number of FINANCE applications are  366
# Total number of FOOD_AND_DRINK applications are  127
# Total number of HEALTH_AND_FITNESS applications are  341
# Total number of HOUSE_AND_HOME applications are  88
# Total number of LIBRARIES_AND_DEMO applications are  85
# Total number of LIFESTYLE applications are  382
# Total number of GAME applications are  1144
# Total number of FAMILY applications are  1972
# ...

# %%
df=data["Type"];
print(df.unique());
# Out:
# ['Free' 'Paid' nan '0']

# %%
df=data.values;
c=0;
for i in df:
    if(i[1]=="ART_AND_DESIGN" and i[6]=="Free"):
        c+=1;
print(c)
# Out:
# 62

# %%
df
# Out:
# array([['Photo Editor & Candy Camera & Grid & ScrapBook',
#         'ART_AND_DESIGN', 4.1, ..., 'January 7, 2018', '1.0.0',
#         '4.0.3 and up'],
#        ['Coloring book moana', 'ART_AND_DESIGN', 3.9, ...,
#         'January 15, 2018', '2.0.0', '4.0.3 and up'],
#        ['U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#         'ART_AND_DESIGN', 4.7, ..., 'August 1, 2018', '1.2.4',
#         '4.0.3 and up'],
#        ...,
#        ['Parkinson Exercices FR', 'MEDICAL', nan, ...,
#         'January 20, 2017', '1.0', '2.2 and up'],
#        ['The SCP Foundation DB fr nn5n', 'BOOKS_AND_REFERENCE', 4.5, ...,
#         'January 19, 2015', 'Varies with device', 'Varies with device'],
#        ['iHoroscope - 2018 Daily Horoscope & Astrology', 'LIFESTYLE',
#         4.5, ..., 'July 25, 2018', 'Varies with device',
#         'Varies with device']], shape=(10841, 13), dtype=object)

# %%
c=0;
for i in df:
    if(i[1]=="ART_AND_DESIGN" and i[2]>4.5 and i[6]=="Free"):
       c+=1;
c
# Out:
# 19

# %%
df=data;
df_pr=df[df["Category"]=="ART_AND_DESIGN"]
df_pr[df_pr["Type"]=="Free"]
# Out:
#                                                     App        Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                   Coloring book moana  ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint  ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                 ...             ...
# 7174                            Easy DIY CD Craft Ideas  ART_AND_DESIGN
# 8679                                       Dp for girls  ART_AND_DESIGN
# 8712             Name Art DP - Focus n Filter Text 2018  ART_AND_DESIGN
# 8871                             Test Application DT 02  ART_AND_DESIGN
# 8888            Spring flowers theme couleurs d t space  ART_AND_DESIGN
#
#       Rating Reviews  Size     Installs  Type Price Content Rating  \
# ...

# %%
df=data;
newDF=df[df["Category"]=="ART_AND_DESIGN"]
len(newDF[newDF["Rating"]>4.5])
# Out:
# 22

# %%
df=data;
newDF=df[df["Type"]=="Free"]
len(newDF[newDF["Rating"]>4.5])
# Out:
# 1709

# %%
df=data;
newDF=((df["Category"]=="ART_AND_DESIGN") & (df["Rating"]>4.5) & (df["Type"]=="Free"))
print(len(df[newDF]))
df[newDF]
# Out:
# 19
#                                                     App        Category  \
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 9                         Kids Paint Free - Drawing Fun  ART_AND_DESIGN
# 13                                Mandala Coloring Book  ART_AND_DESIGN
# 16         Photo Designer - Write your name with shapes  ART_AND_DESIGN
# 19                                         ibis Paint X  ART_AND_DESIGN
# 22              Superheroes Wallpapers | 4K Backgrounds  ART_AND_DESIGN
# 24                          HD Mickey Minnie Wallpapers  ART_AND_DESIGN
# 25                           Harley Quinn wallpapers HD  ART_AND_DESIGN
# 26                        Colorfit - Drawing & Coloring  ART_AND_DESIGN
# 34                                      I Creative Idea  ART_AND_DESIGN
# 36       UNICORN - Color By Number & Pixel Art Coloring  ART_AND_DESIGN
# 38                       PIP Camera - PIP Collage Maker  ART_AND_DESIGN
# ...

# %%
df=data;
newDF=df[df["Type"]=="Free"]
newDF=newDF[newDF["Rating"]>4.5]
newDF.sort_values(by="Rating", ascending=True)
# Out:
#                                                      App           Category  \
# 89     Zona Azul Digital Fácil SP CET - OFFICIAL São ...  AUTO_AND_VEHICLES
# 88           AutoScout24 Switzerland – Find your new car  AUTO_AND_VEHICLES
# 75                 Super Cars Wallpapers And Backgrounds  AUTO_AND_VEHICLES
# 63                         Free VIN Report for Used Cars  AUTO_AND_VEHICLES
# 94     Used car is the first car - used car purchase,...  AUTO_AND_VEHICLES
# ...                                                  ...                ...
# 10629                                Florida Wildflowers             FAMILY
# 10621                        Florida Beach Wallpapers HD   TRAVEL_AND_LOCAL
# 10611                         Beacon Baptist Jupiter, FL          LIFESTYLE
# 10609                         Trinity Church Deltona, FL          LIFESTYLE
# 329                         Hojiboy Tojiboyev Life Hacks             COMICS
#
# ...

# %%
newDF["Reviews"].dtype
# Out:
# dtype('O')

# %%
# int(newDF["Reviews"])
# df.isna().sum()
df=df.dropna()
df.isna().sum()
df.groupby("Category")["Rating"].mean().sort_values(ascending=False)
# Out:
# Category
# EVENTS                 4.435556
# EDUCATION              4.389032
# ART_AND_DESIGN         4.377049
# BOOKS_AND_REFERENCE    4.346067
# PERSONALIZATION        4.335256
# PARENTING              4.300000
# GAME                   4.286326
# BEAUTY                 4.278571
# HEALTH_AND_FITNESS     4.277104
# SHOPPING               4.259664
# SOCIAL                 4.255598
# WEATHER                4.244000
# SPORTS                 4.223511
# PRODUCTIVITY           4.211396
# HOUSE_AND_HOME         4.197368
# FAMILY                 4.192383
# PHOTOGRAPHY            4.192114
# AUTO_AND_VEHICLES      4.190411
# MEDICAL                4.189143
# LIBRARIES_AND_DEMO     4.179688
# FOOD_AND_DRINK         4.166972
# COMMUNICATION          4.158537
# COMICS                 4.155172
# NEWS_AND_MAGAZINES     4.132189
# FINANCE                4.131889
# ENTERTAINMENT          4.126174
# BUSINESS               4.121452
# TRAVEL_AND_LOCAL       4.109292
# LIFESTYLE              4.094904
# ...

# %%
df.groupby("Category")["Type"].count().sort_values(ascending=False)
# Out:
# Category
# FAMILY                 1746
# GAME                   1097
# TOOLS                   733
# PRODUCTIVITY            351
# MEDICAL                 350
# COMMUNICATION           328
# FINANCE                 323
# SPORTS                  319
# PHOTOGRAPHY             317
# LIFESTYLE               314
# PERSONALIZATION         312
# BUSINESS                303
# HEALTH_AND_FITNESS      297
# SOCIAL                  259
# SHOPPING                238
# NEWS_AND_MAGAZINES      233
# TRAVEL_AND_LOCAL        226
# DATING                  195
# BOOKS_AND_REFERENCE     178
# VIDEO_PLAYERS           160
# EDUCATION               155
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     124
# FOOD_AND_DRINK          109
# HOUSE_AND_HOME           76
# WEATHER                  75
# AUTO_AND_VEHICLES        73
# LIBRARIES_AND_DEMO       64
# ART_AND_DESIGN           61
# COMICS                   58
# PARENTING                50
# EVENTS                   45
# ...
